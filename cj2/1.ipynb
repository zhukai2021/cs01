# %%
import json
import requests
sz1=['https://v.douyin.com/A18P886/', 'https://v.douyin.com/A18hWN8/', 'https://v.douyin.com/A18DLeV/', 'https://v.douyin.com/A18r4sQ/', 'https://v.douyin.com/A18SWFC/', 'https://v.douyin.com/A18DVGR/', 'https://v.douyin.com/A18yPUq/', 'https://v.douyin.com/A188Nrr/', 'https://v.douyin.com/A186uFa/', 'https://v.douyin.com/A18rGdB/', 'https://v.douyin.com/A18FkrF/', 'https://v.douyin.com/A18hgws/', 'https://v.douyin.com/A188kkm/', 'https://v.douyin.com/A18j9tb/', 'https://v.douyin.com/A18P7LL/', 'https://v.douyin.com/A18fmBw/', 'https://v.douyin.com/A18hVyv/', 'https://v.douyin.com/A18M9td/', 'https://v.douyin.com/A18PSxy/', 'https://v.douyin.com/A18PMQV/', 'https://v.douyin.com/A18SgFK/', 'https://v.douyin.com/A18eBdM/', 'https://v.douyin.com/A18ehKP/', 'https://v.douyin.com/A18Rxn9/', 'https://v.douyin.com/A18Utme/', 'https://v.douyin.com/A186UDF/', 'https://v.douyin.com/A186dT1/', 'https://v.douyin.com/A188uco/', 'https://v.douyin.com/A18LY7c/', 'https://v.douyin.com/A18BNER/', 'https://v.douyin.com/A188qQd/', 'https://v.douyin.com/A18SuWL/', 'https://v.douyin.com/A182n9N/', 'https://v.douyin.com/A18eAxs/', 'https://v.douyin.com/A18BKC3/', 'https://v.douyin.com/A18UNyh/', 'https://v.douyin.com/A185vp5/', 'https://v.douyin.com/A18UFL2/', 'https://v.douyin.com/A18SuDY/', 'https://v.douyin.com/A18D45s/', 'https://v.douyin.com/A18rCvt/', 'https://v.douyin.com/A18wBjE/', 'https://v.douyin.com/A184AME/', 'https://v.douyin.com/A18v2rA/', 'https://v.douyin.com/A184D8R/', 'https://v.douyin.com/A18cuP6/', 'https://v.douyin.com/A18st9V/', 'https://v.douyin.com/A18XH9v/', 'https://v.douyin.com/A18H43f/', 'https://v.douyin.com/A18W7eU/', 'https://v.douyin.com/A18xyB7/', 'https://v.douyin.com/A18GmMp/', 'https://v.douyin.com/A18Cg8d/', 'https://v.douyin.com/A18w24L/', 'https://v.douyin.com/A184deD/']
i0=1
for url1 in sz1:
    url2='https://tenapi.cn/v2/video?ur'+url1
    r = requests.get(url=url2)
    data_json = json.loads(r.text)
    print(data_json['images'])
    i1=1
    for da1 in data_json['images']:
        print(da1)
        response = requests.get(da1)
        if response.status_code == 200:
        # 从响应中获取图片内容并保存到文件
            with open('x1/'+'A1-'+str(i0)+'-'+str(i1)+'.mp4', "wb") as f:
                f.write(response.content)
            print("图片已下载")
        else:
            print("下载失败")
        i1=i1+1
    i0=i0+1
# Out:
# 图片已下载
# https://p6-sign.douyinpic.com/tos-cn-i-0813c001/364020ed904c4ccea331c56cf9503d52~tplv-dy-aweme-images:q75.webp?x-expires=1681405200&x-signature=RK66ky1F%2F0x7fcv%2B%2FhvuE0VNyiU%3D&from=3213915784&s=PackSourceEnum_AWEME_DETAIL&se=false&biz_tag=aweme_images&l=2023033101073581897FEEF6ED5B2D9B1A
    data_json = json.loads(r.text)
    print(data_json['data']['url'])
    print(data_json['data']['title'])
    response = requests.get(data_json['data']['url'])

    txt_file = 'x2/data.txt'

    with open(txt_file, 'a') as file:
        file.write(str(i1)+'---'+data_json['data']['title']+'---'+data_json['data']['url']+'\n')

    print('文本已保存到TXT文件。')




    if response.status_code == 200:
    # 从响应中获取图片内容并保存到文件
        with open('x2/'+'A1-'+str(i1)+'.mp4', "wb") as f:
            f.write(response.content)
        print("图片已下载")
    else:
        print("下载失败")
  
    i1=i1+1
# Out:
# https://v5-dy-o-abtest.zjcdn.com/f1ab35f7a41f5882b9162c173535063a/65137c89/video/tos/cn/tos-cn-ve-15c001-alinc2/owBvwYwb9lDcANAfBqnBjH8ENBDAgAOgWeMIRA/?a=1128&ch=26&cr=3&dr=0&lr=all&cd=0%7C0%7C0%7C3&cv=1&br=1381&bt=1381&cs=0&ds=6&ft=F-_ezGTe0BN1w3vjVQwGqX.7usSlvkMnaglc&mime_type=video_mp4&qs=0&rc=Ojs2ZzM5NGk1N2g6ZmhoZkBpM3VkdTY6ZnA3bjMzNGkzM0BeYzBjNmMuXmExMjEwYjQ2YSNyZS5mcjQwMC1gLS1kLWFzcw%3D%3D&btag=e000a8000&cc=46&dy_q=1695772174&l=2023092707493483C402AD3BEB4858BF93
# 这首歌能让你刹车成功吗#坏女孩 #音乐
# 文本已保存到TXT文件。
# 图片已下载
# https://v5-dy-o-abtest.zjcdn.com/d1a9ecfa4919970bd3a2d41ec3930d6d/65137c69/video/tos/cn/tos-cn-ve-15c001-alinc2/ocYbvesdAkZ76nBCI8EBHbKDXRDBfJoGAgCfQv/?a=1128&ch=26&cr=3&dr=0&lr=all&cd=0%7C0%7C0%7C3&cv=1&br=1583&bt=1583&cs=0&ds=6&ft=F-_ezGTe0BN1w3vjVQ5GqX.7usSlvkMnaglc&mime_type=video_mp4&qs=0&rc=ZGc1NGlnOmc5ODhmNDQ2ZkBpMzQ5dzM6ZjRpbTMzNGkzM0BeYTQ0YWMvX14xLWMzYjNiYSNjbXBqcjRvanNgLS1kLTBzcw%3D%3D&btag=e000a8000&cc=46&dy_q=1695772187&l=202309270749476A01575F34F34159627B
# ...

# %%
import requests
import time

# 获取当前时间戳（秒级）
timestamp = int(time.time()*1000)
print(timestamp)

# 定义要发送的数据
data = {
    'url': 'https://v.douyin.com/ienjfwUa'
    
}

# 发送POST请求
response = requests.post('https://tenapi.cn/v2/video', data=data)
# 检查响应状态码
if response.status_code == 200:
    # 请求成功
    print('登录成功！')
    print('响应内容:', response.text)
else:
    # 请求失败
    print('登录失败！')
    print('失败原因:', response.text)
# Out:
# 1695771623889
# 登录成功！
# 响应内容: {
#     "code": 200,
#     "msg": "success",
#     "data": {
#         "title": "“以后太远了 我要眼前的此刻”#国庆来赤水做一场江湖山水梦     #赤水丹霞大瀑布",
#         "author": "Li十七呀",
#         "avatar": "https:\/\/p3.douyinpic.com\/aweme\/1080x1080\/aweme-avatar\/tos-cn-avt-0015_923c58c9abf08da1ffe131c4a4af88bf.webp?from=116350172",
#         "like": 36641,
#         "time": 1695555076,
#         "cover": "https:\/\/p11-sign.douyinpic.com\/tos-cn-p-0015\/2189496acac543ce9d3d5873e94adbbd_1695555079~tplv-dy-360p.webp?x-expires=1696978800&x-signature=VKRmtFtsNs7OG6wo1fnJ6LgJOnM%3D&from=3213915784&s=PackSourceEnum_AWEME_DETAIL&se=false&sc=origin_cover&biz_tag=aweme_video&l=20230927074026368DAF37B56EEC490162",
# ...

# %%
import requests
import time

# 获取当前时间戳（秒级）
timestamp = int(time.time()*1000)
print(timestamp)

# 定义要发送的数据
data = {
    'lang': 'zh-hans',
    'video_link': 'https://v.douyin.com/ienjfwUa/ ',
    'id': '9f062a5875236648',
    'key': 'faa0f378ef4c7f4f4fb060a03650051d'
    
}

# 发送POST请求
response = requests.post('https://api.dwtik.app/parser', data=data)
print(f'https://api.spapi.cn/api/parsing?otype=json&timestamp={timestamp}&sign=1600e0d36839305acee39e444bf0c39b')
# 检查响应状态码
if response.status_code == 200:
    # 请求成功
    print('登录成功！')
    print('响应内容:', response.text)
else:
    # 请求失败
    print('登录失败！')
    print('失败原因:', response.text)
# Out:
# 1695652603473
# https://api.spapi.cn/api/parsing?otype=json&timestamp=1695652603473&sign=1600e0d36839305acee39e444bf0c39b
# 登录成功！
# ...

# %%
from selenium.webdriver.common.by import By
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from lxml import etree
import re
import pyperclip
options = webdriver.ChromeOptions()
# options.add_argument('--headless')# 无界面
# options.add_argument('--disable-gpu')#禁用GPU
# options.add_experimental_option('excludeSwitches', ['enable-automation'])# 设置为开发者模式
# options.add_argument("--disable-blink-features=AutomationControlled")#防止检测
options.add_experimental_option("debuggerAddress", "127.0.0.1:9527")
web = webdriver.Chrome(options=options)
# headers = {
#     'content-type': 'application/json',
#     # 'Cookie': 'clientid=3; did=web_e2bb6fd1fd7b3657c30500605fa62386; client_key=65890b29; userId=1901499766; kpf=PC_WEB; kpn=KUAISHOU_VISION; kuaishou.server.web_st=ChZrdWFpc2hvdS5zZXJ2ZXIud2ViLnN0EqABmi3C17zqPQakAOELx56nLw29oSiIMUUzwqxVLr0sGBh8ELiwODmiHvUw640HPd8VWsQxfWXY1YvrsExuKz-o-PkVk3nYIq42ywsVX96Wn75JlOZFSPKa_X7BSqsSwUzafWGIL0b9OyUbYTfJslZuvy9NiTzA14Z2Q3rYf1IfTJKih8-6HVphZxiXFQ0ozO2hEozKbGwHcmB_MMy2rF7tYRoSuDcrlwmr6APhXfdZrBO5uo0FIiBY7507ZbwWPed4-JSGCqQ0KmEvFiperw0f53K92GtC9CgFMAE; kuaishou.server.web_ph=4484357fdb26f29c2bad73ee64a5391bb0d7',
#     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36'
# }
jg1=[]
jg2=[]
#print(web.current_url)
while 1:
    dz1 = web.current_url
    time.sleep(2)
    #web.find_element(By.ID,'root').send_keys(Keys.DOWN)

    #print(web.current_url)
    #print(web.page_source)
    #mouse = web.find_element(By.XPATH,'//*[@id=\"douyin-right-container\"]/div[2]/main/div[1]/div[2]/div/div[1]/div[4]')
    mouse = web.find_element(By.XPATH,'//*[@id=\"sliderVideo\"]/div[1]/div[1]/div/div[1]/div[2]/div[5]')

    ActionChains(web).move_to_element(mouse).perform()
    time.sleep(2)
    e=web.find_element(By.XPATH,"//*[@id=\"sliderVideo\"]/div[1]/div[1]/div/div[1]/div[2]/div[5]/div[2]/div/div/div/button[4]")

    #web.swich_to.frame(e)
    e.click()
    #web.execute_script('arguments[0].click()',e)
    b = pyperclip.paste() # 粘贴的内容，甚至可以存在变量
    # pyperclip.copy("")  # 清空
    print(f"我是复制的内容：{b}")
    b1 = re.findall('https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+/\w+/',b)
    b2 = re.findall('/(.*?)http', b)
    print(b1[0])
    print(b2[0])
    jg1.append(b1[0])
    jg2.append(b2[0])
    time.sleep(2)

    ActionChains(web).send_keys(Keys.UP).perform()

    if web.current_url == dz1:
        print('没有了')
        break
print(jg1)
print(jg2)
with open('test1.txt','w') as f:
   f.write(jg1)
with open('test2.txt','w') as f:
   f.write(jg2)
# Out:
# 我是复制的内容：2.35 iPk:/  # 微信 # 微信8 # 手机 # 安卓 # 苹果 # iOS微信真的会转发文件存十份吗？我发现并没有...  https://v.douyin.com/iDe2XUc/ 复制此链接，打开Dou音搜索，直接观看视频！
# https://v.douyin.com/iDe2XUc/
#   # 微信 # 微信8 # 手机 # 安卓 # 苹果 # iOS微信真的会转发文件存十份吗？我发现并没有...
# 我是复制的内容：7.10 YMj:/   https://v.douyin.com/iDJKk9P/ 复制此链接，打开Dou音搜索，直接观看视频！
# https://v.douyin.com/iDJKk9P/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 27
#      25 while 1:
#      26     dz1 = web.current_url
# ---> 27     time.sleep(2)
#      28     #web.find_element(By.ID,'root').send_keys(Keys.DOWN)
#      29
#      30     #print(web.current_url)
#      31     #print(web.page_source)
#      32     #mouse = web.find_element(By.XPATH,'//*[@id=\"douyin-right-container\"]/div[2]/main/div[1]/div[2]/div/div[1]/div[4]')
#      33     mouse = web.find_element(By.XPATH,'//*[@id=\"sliderVideo\"]/div[1]/div[1]/div/div[1]/div[2]/div[5]')
#
# ...

# %%
pip install pypinyin cnstroke -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
from selenium.webdriver import Chrome
from lxml import etree
import time
import json
from selenium.webdriver.common.by import By
from selenium import webdriver
import re
from bs4 import BeautifulSoup
import csv
from selenium.webdriver.common.keys import Keys
import requests
import json
import csv
from urllib import parse

options = webdriver.ChromeOptions()
# options.add_argument('--headless')# 无界面
# options.add_argument('--disable-gpu')#禁用GPU
# options.add_experimental_option('excludeSwitches', ['enable-automation'])# 设置为开发者模式
# options.add_argument("--disable-blink-features=AutomationControlled")#防止检测
options.add_experimental_option("debuggerAddress", "127.0.0.1:9527")
web = webdriver.Chrome(options=options)
headers = {
    'User-Agent': "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.80 Mobile Safari/537.36 Edg/98.0.1108.43"
}

# print(div1)
# print(len(div1))

for i in range(15000):
    div1 = web.find_elements(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[3]/div/div/div[3]/div[2]/div/div[2]/div/div')
    div1 = div1[0].get_attribute('innerHTML')
    web.find_element(By.TAG_NAME, 'body').send_keys(Keys.END)
    time.sleep(1)
    if div1 == '暂时没有更多了':
        print('到底了')
        break
    else:
        print('还没有到底')
li1 = web.find_elements(By.TAG_NAME, 'ul')[-1].find_elements(By.TAG_NAME,
                                                             'li')  # .find_elements(By.TAG_NAME,'img')#.get_attribute('innerHTM')
i1=1
for li2 in li1:
    # try:
    img2 = li2.find_element(By.TAG_NAME, 'img').get_attribute('alt')
    url2 = li2.find_element(By.TAG_NAME, 'a').get_attribute('href')
    print(url2)
    print(img2)
    url3='https://api.iculture.cc/api/video/?url='+url2
    r = requests.get(url=url3)
    data_json = json.loads(r.text)
    print(data_json['url'])
  
    response = requests.get(data_json['url'])
    if response.status_code == 200:
    # 从响应中获取图片内容并保存到文件
        with open('x1/'+'A-'+str(i1)+'.mp4', "wb") as f:
            f.write(response.content)
        print("视频已下载")
    else:
        print("下载失败")
    i1=i1+1
# Out:
# 到底了
# https://www.douyin.com/video/7242149309389622540
# 奶油小灵：短发还得是#果果不一样 #短发 #颜值
# https://v11-cold1.douyinvod.com/de45244c7a8ec587f75be833ac457426/64ba39ec/video/tos/cn/tos-cn-ve-15c001-alinc2/oIGICAukKCQqwhEyqQftABgN4NZRQCIpeBzGA2/?a=1128&ch=26&cr=3&dr=0&lr=all&cd=0%7C0%7C0%7C3&cv=1&br=1301&bt=1301&cs=0&ds=6&ft=nK5C30071FOvWHhWH6xRfjDcR4BO5aF.Kx2z7tG&mime_type=video_mp4&qs=0&rc=Njg1aTY8aDhkOjY8M2ZpZ0BpM3I1azk6ZnVubDMzNGkzM0A1YWEyMy1hNi0xMDMvYjNhYSMucWpocjRfZC1gLS1kLS9zcw%3D%3D&l=20230721145515A7630C0D6AF6A2084EED&btag=e00088000&dy_q=1689922516
# 视频已下载
# https://www.douyin.com/video/7258116596030344460
# 奶油小灵：没见过bt 可以艾特一个吗
# ...

# %%
import cv2
import os

# 读取文件夹中的所有图片
path = 'x'
for nu in range(1,56):
    image_files = [os.path.join(path, f) for f in os.listdir(path) if f.startswith('A-'+str(nu)+'-')]
    print(image_files)

    # 设置视频编解码器
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')

    # 获取第一张图像的大小
    img = cv2.imread(image_files[0])
    height, width, layers = img.shape

    # 创建视频写入器
    video = cv2.VideoWriter('xx/'+'A-'+str(nu)+'.mp4', fourcc, 12, (width,height))

    # 逐帧将图像写入视频
    for image in image_files:
        frame = cv2.imread(image)
        a = 0
        while a < 6:
            video.write(frame)
            #img = cv2.resize(img, (1125, 2436))
            a += 1

    for image in image_files:
        frame = cv2.imread(image)
        a = 0
        while a < 24:
            video.write(frame)
            #img = cv2.resize(img, (1125, 2436))
            a += 1    

# 释放视频写入器和摄像头资源
cv2.destroyAllWindows()
video.release()

# %%
import cv2
import os

# 读取文件夹中的所有图片
path = 'xx'
image_files = [os.path.join(path, f) for f in os.listdir(path) if f.startswith('1 - 副本')]
print(image_files)

# %%
import os
folder_path = "my_folder"

# 如果文件夹不存在，则创建它
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
    print(f"文件夹 {folder_path} 已创建")
else:
    print(f"文件夹 {folder_path} 已存在")

# %%
pip install opencv-python -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simpleNote: you may need to restart the kernel to use updated packages.
#
# ...
#      ---------------------------------------- 38.1/38.1 MB 9.2 MB/s eta 0:00:00
# ...

# %%
import os
import glob
WSI_MASK_PATH = 'xx'#存放图片的文件夹路径
paths = glob.glob(os.path.join(WSI_MASK_PATH, '*.jpg'))
print(os.getcwd())

print(paths)
paths.sort()
print(paths)

# %%
from PIL import Image

# 打开4张图片
image1 = Image.open("1.jpg")
width1, height1 = image1.size
image2 = Image.open("2.jpg")
image3 = Image.open("6.jpg")
#image4 = Image.open("4.jpg")

# 获取每张图片的宽度和高度
width, height = image1.size

# 创建一个新的空白图片，宽度为原图片宽度的两倍，高度为原图片高度的两倍
new_image = Image.new('RGB', (width*2, height*2))

# 将4张图片按顺序拼接在新图片上
new_image.paste(image1, (0, 0))
new_image.paste(image2, (width, 0))
new_image.paste(image3, (0, height))
#new_image.paste(image4, (width, height))
new_image = new_image.resize((width1, height1))

# 保存新图片
new_image.save("new_image.jpg")

# %%
import cv2
from PIL import Image

# 加载两张图片
image1 = Image.open("1.jpg")
width1, height1 = image1.size
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')

# 将两张图片缩放到相同的大小

print(width1, height1)

# 设置转场时间
transition_time = 5

# 创建转场视频
out = cv2.VideoWriter('transition.avi', cv2.VideoWriter_fourcc(*'XVID'), 30, (width1, height1))

# 循环生成每一帧画面
for i in range(0, 100):
    # 计算当前帧的透明度
    alpha = i / 100.0

    # 使用addWeighted函数混合两张图片
    img = cv2.addWeighted(img1, 1-alpha, img2, alpha, 0)

    # 将当前帧写入视频文件
    out.write(img)

# 释放资源
out.release()
cv2.destroyAllWindows()
# Out:
# 1440 2560

# %%
import cv2
import numpy as np
import os
from PIL import Image
import cv2
import os



def percent_func_gen(a, b, time, n, mode):
    """
    高次多项式计算函数生成器
    :param a: 起始百分比（如：0.25）
    :param b: 结束百分比
    :param time: 动画持续时间
    :param n: 多项式次数
    :param mode: faster（越来越快）、slower（越来越慢）
    :return: 每个时刻到达百分比的计算函数
    """
    if mode == "slower":
        a, b = b, a
    delta = abs(a - b)
    sgn = 1 if b - a > 0 else (-1 if b - a < 0 else 0)

    def percent_calc(ti):
        if mode == "slower":
            ti = time - ti
        return sgn * delta / (time ** n) * (ti ** n) + a

    return percent_calc


'''读入图像'''
img1 = cv2.imread("1.jpg")
img2 = cv2.imread("2.jpg")
rows, cols = img1.shape[:2]

'''特效展示'''
load_f = 20
tim = 0.3
percent_func = percent_func_gen(a=0, b=1, time=tim, n=1, mode="null")
for t in range(int(tim * 1000) // load_f + 1):
    percent = percent_func(t * load_f / 1000)
    height = int(percent * rows)
    img1[:height, :] = img2[:height, :]
    # cv2.imshow("show", img1)
    # cv2.waitKey(load_f)
   
 

'''关闭窗口'''

# cv2.waitKey(6000)
# cv2.destroyAllWindows()

# %%
import threading
import time

def worker():
    while True:
        print('Worker running')
        time.sleep(1)

t = threading.Thread(target=worker)
t.daemon = True
t.start()

print('Main thread exiting')
