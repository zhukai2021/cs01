# %%
# 导入库
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from lxml import etree # 导入etree模块

# 定义请求头
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# 定义初始网址
start_url = 'https://www.xiaohongshu.com/user/profile/581535d16a6a694890abae38'

# 定义空列表，用于存储数据
note_links = [] # 笔记链接

# 发送请求，获取响应
response = requests.get(start_url, headers=headers)
# 解析响应，得到HTML文本
html = response.text
#print(html)
# 使用BeautifulSoup解析HTML文本
pattern = r'href="/explore/(\w+)"'  # 匹配 href="/explore/" 后面的一串字符

matches = re.findall(pattern, html)  # 使用 findall 方法找到所有匹配项
#新建空数组
wz1 = []
if matches:
    # 打印所有匹配项
    for match in matches:
        url = "https://www.xiaohongshu.com/explore/" + match
        #print(url)
        wz1.append(url)
        #print(match)
else:
    print("没有找到匹配项")
print(wz1)    

#遍历数组wz1
for wz2 in wz1:

    # 发送请求，获取响应
    response = requests.get(wz2, headers=headers)
    # 解析响应，得到_Element对象
    html = etree.HTML(response.text) # 使用etree.HTML()函数解析HTML文本
    # 提取description的content，使用html.xpath()方法
    title = html.xpath('//meta [@name="title"]/@content') # 得到一个列表，包含description的content
    description = html.xpath('//meta [@name="description"]/@content') # 得到一个列表，包含description的content
    # 列表中只有一个元素，取出来赋值给一个变量
    title = title[0]
    description = description[0]
    print(title)

    # 打印description的content
    print(title+'--'+description)
    # description保存到1.csv
    with open('1.csv', 'a', encoding='utf-8') as f:
        f.write(title+'--'+description + '\n')
# Out:
# 转换完成！

# %%
# 导入库
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from lxml import etree # 导入etree模块
import csv

# 定义请求头
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# 定义初始网址
url = 'https://www.wenanwang.com/lz/760.html'


# 发送请求，获取响应
response = requests.get(url=url, headers=headers)
response.encoding = 'utf-8' 
#print(response.text)
# 解析响应，得到_Element对象
html = etree.HTML(response.text) # 使用etree.HTML()函数解析HTML文本
print(html)
nr1= html.xpath('//*[@id="ML"]/div[1]/div[2]/p/text()')
print(nr1)  
with open('8.csv', mode='w', newline='') as file:  
    writer = csv.writer(file)  
    writer.writerow(['NO', '文案'])  # 写入标题行
  
    # 依次写入每个文本元素  
    for text in nr1:  
        array = text.split('.')  

        writer.writerow(array)
# with open('2.csv', 'w', newline='') as csvfile:  
#     writer = csv.writer(csvfile)  
#     for num in sz1:  
#         writer.writerow([num])
# Out:
# <Element html at 0x13ce3148b40>
# ...

# %%
# 导入库
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from lxml import etree # 导入etree模块
import csv

# 定义请求头
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# 定义初始网址
url = 'https://www.wenanwang.com/lz/1650.html'


# 发送请求，获取响应
response = requests.get(url=url, headers=headers)
response.encoding = 'utf-8' 
#print(response.text)
# 解析响应，得到_Element对象
html = etree.HTML(response.text) # 使用etree.HTML()函数解析HTML文本
print(html)
nr1= html.xpath('//*[@id="ML"]/div[1]/div[2]/p/text()')
print(nr1)  
with open('8-1.csv', mode='w', newline='') as file:  
    writer = csv.writer(file)  
    writer.writerow(['NO', '文案'])  # 写入标题行
  
    # 依次写入每个文本元素  
    for text in nr1:  
        array = text.split('、')  

        writer.writerow(array)
# with open('2.csv', 'w', newline='') as csvfile:  
#     writer = csv.writer(csvfile)  
#     for num in sz1:  
#         writer.writerow([num])
# Out:
# <Element html at 0x2787f7a7a80>
# ...

# %%
from vika import Vika
vika = Vika("uskf7jQK6SWEPXaPaeR6rGY")
# 通过 datasheetId 来指定要从哪张维格表操作数据。
datasheet = vika.datasheet("dstFUySTnbUHSqFCGg", field_key="name")
row = datasheet.records.create({
  "NO": 1,
  "文案": "就因为太爱那个人，所以才没敢告诉他，你走之后我真想你啊。也因为你不会回来，所以我要努力克制自己，在回忆里做个体面人。"
})

# %%
import requests  
  
url = 'https://api.vika.cn/fusion/v1/datasheets/dstHsQXXPilwsiHrLw/records?viewId=viwxQVYUoceQk&fieldKey=name'  
headers = {'Authorization': 'Bearer uskf7jQK6SWEPXaPaeR6rGY'}  
  
response = requests.get(url, headers=headers)  
print(response.text)
# Out:
# {"code":200,"success":true,"data":{"total":101,"records":[{"recordId":"recCu4Qgzpw5C","createdAt":1705749441000,"updatedAt":1705749441000,"fields":{"NO":"1","情感":"就因为太爱那个人，所以才没敢告诉他，你走之后我真想你啊。也因为你不会回来，所以我要努力克制自己，在回忆里做个体面人。"}},{"recordId":"recgM6URbfSkD","createdAt":1705749441000,"updatedAt":1705749441000,"fields":{"NO":"2","情感":"真正爱你的人 \r\n是在你最丑陋的时光里 \r\n将你的好坏一并包容的人  ​​​​"}},{"recordId":"recPYVptJCy7w","createdAt":1705749441000,"updatedAt":1705749441000,"fields":{"NO":"3","情感":"有时候，我们就像鱼缸里的鱼，想说的话很多，一开口就化成了一串省略号。。。。最后都默默的留在了心里。。。 ​​​​"}},{"recordId":"recEC2jxzfnfM","createdAt":1705749441000,"updatedAt":1705749441000,"fields":{"NO":"4","情感":"习惯了不该习惯的习惯，却执着着不该执着的执着。有时候，在乎得太多，对自己而言也是一种折磨。 ​​​​"}},{"recordId":"recY2XdSAu1Sb","createdAt":1705749441000,"updatedAt":1705749441000,"fields":{"NO":"5","情感":"喜欢上你，并不是你长的好不好看的原因，而是你在特殊的时间里给了我别人给不了的感觉。"}},{"recordId":"recppkU9qerlk","createdAt":1705749441000,"updatedAt":1705749441000,"fields":{"NO":"6","情感":"眼泪真正的作用是洗净眼睛，要你看清楚让你落泪的那个人。眼泪也是当你无法用嘴来解释你的
# ...

# %%
from vika import Vika
vika = Vika("uskf7jQK6SWEPXaPaeR6rGY")
# 通过 datasheetId 来指定要从哪张维格表操作数据。
datasheet = vika.datasheet("dstHsQXXPilwsiHrLw", field_key="id")
# 返回所有记录的集合
records = datasheet.records.all()
for record in records:
  print(record.json())

# 指定视图id，只返回该视图的记录
records_via_view = datasheet.records.all(viewId="viwxQVYUoceQk")
# 查找并返回一条记录（如果存在多条，则返回第一条），一般通过唯一标识获取单条记录。
one_record = datasheet.records.get(fld4vYQMafdhH="1")
# 查询并返回符合条件的记录数组，不加条件效果和 all 相同
records = datasheet.records.filter(fld4vYQMafdhH="1")

# %%
# 导入库
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from lxml import etree # 导入etree模块
import csv

# 定义请求头
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}
wz1 = []
# 定义初始网址
for i1 in range(1,8):
    url = f'https://so.gushiwen.cn/mingjus/default.aspx?page={i1}&tstr=思乡&astr=&cstr=&xstr='
    print(url)
    #print(url)
    # 发送请求，获取响应
    response = requests.get(url, headers=headers)
    # 解析响应，得到HTML文本
    html = response.text
    #print(html)
    # 使用BeautifulSoup解析HTML文本
    #pattern = r'/mingju/juv([^\s]+)\.aspx'  # 匹配 href="/explore/" 后面的一串字符
    pattern = r'/mingju/juv[^\s]+\.aspx'

    matches = re.findall(pattern, html)  # 使用 findall 方法找到所有匹配项


    if matches:
        # 打印所有匹配项
        for match in matches:
            url =  'https://so.gushiwen.cn'+match
            #print(url)
            wz1.append(url)
            #print(match)
    else:
        print("没有找到匹配项")
#print(wz1)    

#遍历数组wz1
sz1=[]
for wz2 in wz1:
    try:  
        print(wz2)
        cs1=[]
        # 发送请求，获取响应
        response = requests.get(wz2, headers=headers)
        # 解析响应，得到_Element对象
        html = etree.HTML(response.text) # 使用etree.HTML()函数解析HTML文本
        print(html)
        nr1= html.xpath('//*[@id="sonsyuanwen"]/div[1]/p/text()[1]')
        print(nr1)
        nr2= html.xpath('//*[@id="sonsyuanwen"]/div[1]/h1/text()')
        nr2a=nr2[0]
        nr2a=nr2a.replace('，', '\n')  
        nr2a=nr2a.replace('。', '') 
        print(nr2a)
        nr3= html.xpath('//*[@id="sonsyuanwen"]/div[1]/p/a/text()')
        print(nr3)
        nr4= html.xpath('//*[@class="contson"]/p/text()')
        # if nr4a is not None:  
        #     print("元素存在")
        #     if len(nr4a)==2:
        #         nr4=nr4a[0]+','+nr4a[1]
        #     if len(nr4a)==1:
        #         nr4=nr4a[0]+','+''
        # else:  
        #     print("元素不存在")
        #     nr4=''
    
        cs1=cs1+[nr2a,nr1[0]+' '+nr3[0]+'《'+nr3[1]+'》',nr4[0]+'\n\n'+nr4[1]]
        print(cs1)
        sz1.append(cs1)
    except:  
        # 当发生其他任何异常时执行的代码块  
        print("发生了未知的异常！")
    #break

 
   
print(sz1)    
with open('5.csv', mode='w', newline='') as file:  
    writer = csv.writer(file)  
    writer.writerow(['句子', '朝代','解释'])  # 写入标题行
  
    # 依次写入每个文本元素  
    for text in sz1:  
        writer.writerow(text)
# with open('2.csv', 'w', newline='') as csvfile:  
#     writer = csv.writer(csvfile)  
#     for num in sz1:  
#         writer.writerow([num])
# Out:
# https://so.gushiwen.cn/mingjus/default.aspx?page=1&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=2&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=3&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=4&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=5&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=6&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=7&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingju/juv_9b295215226f.aspx
# <Element html at 0x14937389cc0>
# ['出自宋代']
# 人言落日是天涯
# 望极天涯不见家
# ['李觏', '乡思']
# ['人言落日是天涯\n望极天涯不见家', '出自宋代 李觏《乡思》', '解释：人们都说太阳落山的地方就是天涯，我竭力朝天涯眺望，也没有看到我的家。\n\n赏析：此句从极远处着笔，写诗人极目天涯时所见所感，极力写出故乡的遥远，流露出诗人的浓郁乡思。']
# https://so.gushiwen.cn/mingju/juv_f3555a375e78.aspx
# <Element html at 0x149375e28c0>
# ['出自唐代']
# 海上生明月
# 天涯共此时
# ['张九龄', '望月怀远']
# ...

# %%
# 导入库
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from lxml import etree # 导入etree模块
import csv

# 定义请求头
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}
wz1 = []
# 定义初始网址
print(1111)
print(start_url)
for i1 in range(1,8):
    url = f'https://so.gushiwen.cn/mingjus/default.aspx?page={i1}&tstr=思乡&astr=&cstr=&xstr='
    print(url)
    #print(url)
    # 发送请求，获取响应
    response = requests.get(start_url, headers=headers)
    # 解析响应，得到HTML文本
    html = response.text
    #print(html)
    # 使用BeautifulSoup解析HTML文本
    #pattern = r'/mingju/juv([^\s]+)\.aspx'  # 匹配 href="/explore/" 后面的一串字符
    pattern = r'/mingju/juv[^\s]+\.aspx'

    matches = re.findall(pattern, html)  # 使用 findall 方法找到所有匹配项


    if matches:
        # 打印所有匹配项
        for match in matches:
            url =  'https://so.gushiwen.cn'+match
            #print(url)
            wz1.append(url)
            #print(match)
    else:
        print("没有找到匹配项")
print(wz1)
# Out:
# 1111
# https://so.gushiwen.cn/mingjus/default.aspx?page=1&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=1&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=2&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=3&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=4&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=5&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=6&tstr=思乡&astr=&cstr=&xstr=
# https://so.gushiwen.cn/mingjus/default.aspx?page=7&tstr=思乡&astr=&cstr=&xstr=
# ...

# %%
# 导入库
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from lxml import etree # 导入etree模块
import csv

# 定义请求头
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# 定义初始网址
start_url = 'https://so.gushiwen.cn/mingjus/default.aspx?page=1&tstr=思乡&astr=&cstr=&xstr='

# 定义空列表，用于存储数据
note_links = [] # 笔记链接

# 发送请求，获取响应
response = requests.get(start_url, headers=headers)
# 解析响应，得到HTML文本
html = response.text
#print(html)
# 使用BeautifulSoup解析HTML文本
#pattern = r'/mingju/juv([^\s]+)\.aspx'  # 匹配 href="/explore/" 后面的一串字符
pattern = r'/mingju/juv[^\s]+\.aspx'

matches = re.findall(pattern, html)  # 使用 findall 方法找到所有匹配项


#新建空数组
wz1 = ['https://so.gushiwen.cn/mingju/juv_bc41a1f7daef.aspx']
# if matches:
#     # 打印所有匹配项
#     for match in matches:
#         url =  'https://so.gushiwen.cn'+match
#         #print(url)
#         wz1.append(url)
#         #print(match)
# else:
#     print("没有找到匹配项")
# print(wz1)    

#遍历数组wz1
sz1=[]
for wz2 in wz1:
    print(wz2)
    cs1=''

    # 发送请求，获取响应
    response = requests.get(wz2, headers=headers)
    # 解析响应，得到_Element对象
    html = etree.HTML(response.text) # 使用etree.HTML()函数解析HTML文本
    print(html)
    nr1= html.xpath('//*[@id="sonsyuanwen"]/div[1]/p/text()[1]')
    print(nr1)
    nr2= html.xpath('//*[@id="sonsyuanwen"]/div[1]/h1/text()')
    print(nr2)
    nr3= html.xpath('//*[@id="sonsyuanwen"]/div[1]/p/a/text()')
    print(nr3)
    nr4a= html.xpath('//*[@class="contson"]/p/text()')
    if nr4a is not None:  
        print("元素存在")
        if len(nr4a)==2:
            nr4=nr4a[0]+','+nr4a[1]
        if len(nr4a)==1:
            nr4=nr4a[0]+','+''
    else:  
        print("元素不存在")
        nr4=''
   
    cs1=nr2[0]+','+nr1[0]+'--'+nr3[0]+'<<'+nr3[1]+'>>,'+nr4
    print(cs1)
    sz1.append(cs1)
   

 
    #break
# Out:
# https://so.gushiwen.cn/mingju/juv_bc41a1f7daef.aspx
# <Element html at 0x149378ca140>
# ['出自唐代']
# ['马上相逢无纸笔，凭君传语报平安。']
# ['岑参', '逢入京使']
# 元素存在
# 马上相逢无纸笔，凭君传语报平安。,出自唐代--岑参<<逢入京使>>,解释：在马上匆匆相逢没有纸笔写书信，只有托你捎个口信，给家人报平安。,赏析：此句写遇到入京使者时欲捎书回家报平安又苦于没有纸笔的情景，简净之中寄寓着诗人的一片深情，寄至味于淡薄，颇有韵味。

# %%
from selenium.webdriver import Chrome
from lxml import etree
import time
import json
from selenium.webdriver.common.by import By
from selenium import webdriver
import re
from bs4 import BeautifulSoup
import csv
from selenium.webdriver.common.keys import Keys
import requests
import json
import csv
from urllib import parse

options = webdriver.ChromeOptions()
# options.add_argument('--headless')# 无界面
# options.add_argument('--disable-gpu')#禁用GPU
# options.add_experimental_option('excludeSwitches', ['enable-automation'])# 设置为开发者模式
# options.add_argument("--disable-blink-features=AutomationControlled")#防止检测
options.add_experimental_option("debuggerAddress", "127.0.0.1:9527")
web = webdriver.Chrome(options=options)
headers = {
    'User-Agent': "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.80 Mobile Safari/537.36 Edg/98.0.1108.43"
}


# 点击图片上传按钮
web.find_element(By.CLASS_NAME, 'soutu-btn').click()
time.sleep(5)
# 找到上传图片元素
upload_pic_input = web.find_element(By.CLASS_NAME, 'upload-pic')
# 直接上传
upload_pic_input.send_keys(r'D:1/9242.PNG')

time.sleep(5)
