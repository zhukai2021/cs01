# %%
from docx import Document  
  
def read_word_file(file_path):  
    document = Document(file_path)  
    content = [] 
    for i,para in enumerate(document.paragraphs):  
        text = para.text.strip()  
        if not text:  
            # 如果段落是空的或只包含空白字符，则跳过当前循环  
            i=i-1
            continue  
        content.append([i,text])
    return content  
  
# 使用示例  
file_path = '1.docx'  # 替换为你的Word文件路径  
content = read_word_file(file_path)  
print(content)
import csv

# 准备数据列表
# data = [
#     ['value1', 'value2', ...],  # 数据项1
#     ['value1', 'value2', ...],  # 数据项2
#     # ...
# ]

# 指定CSV文件路径
csv_file = 'data.csv'

# 打开CSV文件并写入数据
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(content )

print('数据写入CSV文件完成。')
# Out:
# [[0, '情感类语录短视频文案——510条15秒'], [1, '就因为太爱那个人，所以才没敢告诉他，你走之后我真想你啊。也因为你不会回来，所以我要努力克制自己，在回忆里做个体面人。'], [2, '真正爱你的人\xa0\n是在你最丑陋的时光里\xa0\n将你的好坏一并包容的人\xa0 \u200b\u200b\u200b\u200b'], [3, '有时候，我们就像鱼缸里的鱼，想说的话很多，一开口就化成了一串省略号。。。。最后都默默的留在了心里。。。 \u200b\u200b\u200b\u200b'], [4, '习惯了不该习惯的习惯，却执着着不该执着的执着。有时候，在乎得太多，对自己而言也是一种折磨。 \u200b\u200b\u200b\u200b'], [5, '喜欢上你，并不是你长的好不好看的原因，而是你在特殊的时间里给了我别人给不了的感觉。'], [6, '眼泪真正的作用是洗净眼睛，要你看清楚让你落泪的那个人。眼泪也是当你无法用嘴来解释你的心碎的时候，用眼睛表达情绪的唯一方式。 \u200b\u200b\u200b\u200b'], [7, '自己想要的东西，要么奋力直追，要么干脆放弃。别总是逢人就喋喋不休的表决心或者哀怨不断，做别人茶余饭后的笑点。 \u200b\u200b\u200b\u200b'], [8, '"当你学会拒绝别人，学会以牙还牙时，他们反而会尊重你， 甚至敬畏你。我终于相信了那句话：无情一点并没有错。 " \u200b\u200b\u200b\u200b'], [9, '总是这样，一瞬间想通了，释然了，在下一秒又想不通了。大道理都懂，可小情绪却难自控。 \u200b\u200b\u200b\u200b'], [10, '你越在意什么，什么就越会折磨你。生活本就不易，不必渴求别人的理解和认同，静静的过自己的生活就好。心若不动，风又奈何，你若不伤，岁月无恙。'], [11, '不要让期望你的人，等待太久。不要让嘲笑你的人，得意太久。不要让疼爱你的人，失望太久。 \u200b\u200b\u200b\u200b'], [12, '有时候，你的好，对别人来说就像一颗糖，吃了就没了。而你的不好，就像一道伤疤，会永远存在。这就是人性。 \u200b\u200b\u200b\u200b'], [13, '直到累了才发现，自己内心的天真与这冷
# ...

# %%
import csv  
  
# 打开CSV文件并读取数据  
with open('8.csv', 'r') as file:  
    reader = csv.reader(file)  
    data = [row for row in reader]  
  
# 打印列表  
#print(data)
#len(data)
sz1=[]
for i0,i in enumerate(range(1, len(data), 5)): 
    str0='' 
    
    for i1,j in enumerate(data[i:i+5]):
        str0+=str(i1+1)+','+j[1]+"\n\n"
    #print(str0)
    sz2=[str(i0+1),(str0)]
    sz1.append(sz2)
print(sz1)


# for a5 in data:

with open('9.csv', mode='w', newline='') as file:  
    writer = csv.writer(file)  
    writer.writerow(['NO', '文案'])  # 写入标题行
    writer.writerows(sz1)

  
#     # 依次写入每个文本元素  
#     for text in nr1:  
#         array = text.split('.')  

#         writer.writerow(array)
# Out:
# [['1', '1,不畏人言，不惧岁月\n\n2,世界上最大的监狱就是你的内心，走不出自己的执念，到哪里都是囚徒。\n\n3,任何事情只要心甘情愿就会变的简单。\n\n4,你织的茧，得你自己去咬破！拯救自己的，只有自己。\n\n5,不可能的事别等别问别回忆别期待。\n\n'], ['2', '1,对任何热爱的事物都要全力以赴\n\n2,可以再浪漫些日落晚风和鲜花。\n\n3,命运有变数，尽力当永恒。\n\n4,努力让自己发光对的人才会迎光而来。\n\n5,与理想平等交易同喧闹保持距离。\n\n'], ['3', '1,你多学一样本事，就少说一句求人的话。\n\n2,做你自己吧没有很好也没关系。\n\n3,不要太想念过去，因它会给你带来悲伤；用微笑活在当下，它会带来喜乐。\n\n4,别总是抱怨生活不够幸运，是你欠了生活一份努力，每一个你讨厌的现在，都有一个不够努力的曾经，未来美不美，取决于你现在拼不拼。\n\n5,你未来的样子藏在你现在的努力里。\n\n'], ['4', '1,一定要变好呀，我才不要做个委屈鬼呀。\n\n2,你要像太阳一样有起有落却不失光彩。\n\n3,如果你看到前面的阴影，别怕，那是因为你背后有阳光。\n\n4,不论做什么事，都要相信你自己，别让别人的一句话将你击倒。人生没有对错，只有选择后的坚持，不后悔，走下去，走着走着，花就开了。\n\n5,乾坤未定，你我皆是黑马!\n\n'], ['5', '1,偷偷厉害万事尽可期待。\n\n2,努力只能及格，拼命才有能优秀。\n\n3,当下每一次想要努力的念头，都是未来的你在求救。\n\n4,如果事情不能用微笑面对，那就用沉默去对抗吧！凡是看淡一点，再淡一点，拳头般大的心，承受不了那么多。\n\n5,人生难免经受挫折，风雨过后就是彩虹；生活难免遭受苦难，雨过天晴终有阳光。\n\n'], ['6', '1,别让平淡生活耗尽所有向往\n\n2,你走过的路，会成为回忆里的风景；你所有经历，会成为你的财富；你曾经的负担，会成为你的礼物；你受的苦，会照亮你未来的路。\n\n3,当你的才华撑不起你的野心时，那你就应该静下心来学习；当你的经济还撑不起你的梦想时，那你就应该踏实的去工作。\n\n4,一直在逞强，只是自己知道，如若不坚强，没人会替我坚强。\n\n5,一直往前走，就会迎面撞上生活给你的糖。\n\n'], [
# ...

# %%
import csv

# 准备数据列表
data = [
    ['value1', 'value2', ...],  # 数据项1
    ['value1', 'value2', ...],  # 数据项2
    # ...
]

# 指定CSV文件路径
csv_file = 'data.csv'

# 打开CSV文件并写入数据
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(data)

print('数据写入CSV文件完成。')
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/239.6 kB ? eta -:--:--
#      ------ ------------------------------ 41.0/239.6 kB 653.6 kB/s eta 0:00:01
#      ----------------- -------------------- 112.6/239.6 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------  235.5/239.6 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 239.6/239.6 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
